# %% [markdown]
# <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg">

# %% [markdown]
# <center><font color=#555555><font size=6> Ingeniería Financiera </font> <br> <br>
#
# <center><font color=#555555><font size=5> ITE1731 - Microestructura y Sistemas de Trading </font> <br> <br> <br>
#
# <center><font color=#555555><font size=5> I.F. Diego Orozco </font> <br> <br>
#
#
#
# <center> <font color= #555555> <font size = 4> 9 de noviembre 2021 </a> | <font color= #555555> <font size = 4> Repositorio: <a href='https://github.com/diegooropa/LAB4'>Link</a></font>

# %% [markdown]
# Las criptomonedas se originaron en 2009, la primera de ellas fue Bitcoin. El objetivo que tenia su creación era brindar una alternativa a las monedas que emiten los bancos centrales. El bitcoin no es nada más que un registro electronico, donde se establece cuantas "monedas" tiene cada usuario.
# Uno de los problemas de bitcoin es que care de valor intrinseco, ya que su precio depende totalmente de la oferta y demanda, pero no hay forma de constatar este valor como "verdadero"

# %% [markdown]
# En este laboratorio se busca conocer el comportamiento del mercado de las criptomedas, donde se busca conocer el ask y bid con sus volumenes, así como el VWAP, todo esto consultando el Libro de Ordenes.

# %% [markdown]
# Para el funcionamiento de este Notebook se requiere tener instaladas las librerias que se encuentran en el file requirements.txt

# %%
from Functions import *
import pickle

# %%
dictionary_1 = open("dic_BTC.pkl", "rb")
a = pickle.load(dictionary_1)
a
# Out:
# {'currency': ['kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'kraken',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
#   'ftx',
# ...

# %%
summary_1 = pd.read_pickle('df_btc.pkl')
summary_1
# Out:
#         currency                    Fechas  Levels  Volume_ask  Volume_bid  \
# 0         kraken  2021-11-10T04:36:44.349Z     100   76.384000      89.926
# 1         kraken  2021-11-10T04:36:47.483Z     100   78.328000      89.570
# 2         kraken  2021-11-10T04:36:50.529Z     100   78.328000      89.570
# 3         kraken  2021-11-10T04:36:53.679Z     100   77.159000      91.045
# 4         kraken  2021-11-10T04:36:56.725Z     100   77.159000      91.045
# ..           ...                       ...     ...         ...         ...
# 187  currencycom  2021-11-10T04:37:04.366Z      20   61.280000      46.490
# 188  currencycom  2021-11-10T04:37:16.374Z      20   60.290000      49.920
# 189  currencycom  2021-11-10T04:37:39.349Z      20   62.790001      49.240
# 190  currencycom  2021-11-10T04:37:40.392Z      20   62.790001      49.240
# 191  currencycom  2021-11-10T04:37:41.455Z      20   62.790001      49.240
#
#      Total_volume  Mid_price          VWAP
# ...

# %%
dictionary_2 = pd.read_pickle("df_ETH.pkl")
dictionary_2
# Out:
#     currency                    Fechas  Levels  Volume_ask  Volume_bid  \
# 0     kraken  2021-11-10T04:37:49.993Z     100    1107.526    1301.072
# 1     kraken  2021-11-10T04:37:53.167Z     100    1107.526    1301.072
# 2     kraken  2021-11-10T04:37:56.323Z     100    1100.178    1332.096
# 3     kraken  2021-11-10T04:37:59.399Z     100    1100.178    1332.096
# 4     kraken  2021-11-10T04:38:02.546Z     100    1064.077    1349.095
# ..       ...                       ...     ...         ...         ...
# 186      ftx  2021-11-10T04:38:42.818Z      20     123.836     119.332
# 187      ftx  2021-11-10T04:38:43.157Z      20     126.728     119.129
# 188      ftx  2021-11-10T04:38:43.501Z      20     142.632     131.274
# 189      ftx  2021-11-10T04:38:43.834Z      20     142.452     134.474
# 190      ftx  2021-11-10T04:38:44.429Z      20     127.818     123.979
#
#      Total_volume  Mid_price         VWAP
# 0        2408.598   4701.185  4703.494183
# ...

# %%
dictionary_3 = pd.read_pickle("df_BNB.pkl")
dictionary_3
# Out:
#     currency                    Fechas  Levels  Volume_ask  Volume_bid  \
# 0     kraken  2021-11-10T04:37:49.993Z     100    1107.526    1301.072
# 1     kraken  2021-11-10T04:37:53.167Z     100    1107.526    1301.072
# 2     kraken  2021-11-10T04:37:56.323Z     100    1100.178    1332.096
# 3     kraken  2021-11-10T04:37:59.399Z     100    1100.178    1332.096
# 4     kraken  2021-11-10T04:38:02.546Z     100    1064.077    1349.095
# ..       ...                       ...     ...         ...         ...
# 186      ftx  2021-11-10T04:38:42.818Z      20     123.836     119.332
# 187      ftx  2021-11-10T04:38:43.157Z      20     126.728     119.129
# 188      ftx  2021-11-10T04:38:43.501Z      20     142.632     131.274
# 189      ftx  2021-11-10T04:38:43.834Z      20     142.452     134.474
# 190      ftx  2021-11-10T04:38:44.429Z      20     127.818     123.979
#
#      Total_volume  Mid_price         VWAP
# 0        2408.598   4701.185  4703.494183
# ...

# %% [markdown]
# ### Conclusiones
#
# En este laboratorio se pudo empezar a conocer como es la estructura de los mercados de cryptomonedas, a pesar de que este mercado es relativamente nuevo en comparación a los mercados tradicionales de divisas, ya es posible estudiarlo y entender su comportamiento.
#
# De las plataformas, Kraken parece ser la más usada ya que los niveles son más altos en comparació a las demás plataformas, por lo que deduciomos que en la que se mueve más volumen es Kraken.
#
# En el Mid_price se puede apreciar un comportamiento similar, donde dependiendo el exchange es el Mid_price por lo cual se esto se puede atribuair a el numero de operaciones realizadas en cada exchange.
#
# En conclusion las cryptomonedas, con todo lo que envuelven son una realidad y parecen ser el futuro en cuanto a transacciones, auqnue no se sabe si se quedaran es estas crypto divisas. Lo que si sabemos hasta el momento, es que la volatilidad que manejan es para tener cuidado, ya que el comportamiento de estas no se puede comparar con las divisas que ya conocemos.
